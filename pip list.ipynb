# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ----------
# absl-py                           0.6.1
# alembic                           1.0.3
# asn1crypto                        0.24.0
# astor                             0.7.1
# async-generator                   1.10
# audioread                         2.1.6
# backcall                          0.1.0
# beautifulsoup4                    4.6.3
# bleach                            3.0.2
# boto                              2.49.0
# boto3                             1.9.63
# botocore                          1.12.63
# Bottleneck                        1.2.1
# bz2file                           0.98
# certifi                           2018.10.15
# cffi                              1.11.5
# chardet                           3.0.4
# Click                             7.0
# cloudpickle                       0.6.1
# conda                             4.5.11
# cryptography                      2.2.2
# ...
